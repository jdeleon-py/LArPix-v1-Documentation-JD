# %%
import larpix
from larpix.larpix import *

# %%
# Creating a LArPix Controller

from larpix.io.fakeio import FakeIO
from larpix.logger.stdout_logger import StdoutLogger
controller = Controller()
controller.io = FakeIO()
controller.logger = StdoutLogger(buffer_length=0)
controller.logger.enable()

# %%
# Setting Up LArPix Chips

chipID = 5
chip_key = '1-1-5'
chip5 = controller.add_chip(chip_key)
chip5 = controller.get_chip(chip_key)

# %%
chip5
# Out:
# Chip(chip_key=1-1-5)

# %%
# chip_key field specifies info for controller.io to route packets to/from the chip
# for each larpix.io class, thr chip key consists of 3 1-byte integer values, specified as:

# IO Group:
    # Highest Layer
    # represents a control sys that communicates with multiple IO channels

# IO Channel:
    # Middle Layer
    # represents a single MOSI/MISO pair

# Chip ID:
    # Lowest Layer
    #represents a single chip on a MISO/MOSI network

# To interact with chip keys directly, use a valid keystring ('#-#-#')

from larpix.larpix import Key

example_key = Key('1-2-3')

print(example_key.io_group)
print(example_key.io_channel)
print(example_key.chip_id)

print(example_key.to_dict())
# Out:
# 1
# 2
# 3
# {'io_group': 1, 'io_channel': 2, 'chip_id': 3}

# %%
# Adjusting the Config of the LArPix chips

chip5.config.global_threshold = 35 # Entire Register = 1 number --- what does this mean?
chip5.config.periodic_reset = 1 # one bit as part of a register
chip5.config.channel_mask[20] = 1 # one bit per channel

# %%
controller.write_configuration(chip_key)
#controller.write_configuration(chip_key, 32)
#controller.write_configuration(chip_key, [32, 50])

# All the registers were sent, an obsevation can be made that there exists 63 registers (0-62)
# Out:
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 0 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 1 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 2 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 3 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 4 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 5 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 6 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 7 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 8 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 9 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 10 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 11 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 12 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 13 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 14 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 15 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 16 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 17 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 18 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 19 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 20 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 21 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 22 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 23 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 24 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 25 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 26 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 27 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 28 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 29 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 30 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 31 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  35 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 33 | Value:  1 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 34 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 35 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 36 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 37 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 38 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 39 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 40 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 41 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 42 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 43 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 44 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 45 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 46 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 47 | Value:  8 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 48 | Value:  1 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 49 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 51 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 52 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 53 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 54 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 55 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 56 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 57 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 58 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 59 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 60 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 61 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 62 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 0 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 1 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 2 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 3 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 4 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 5 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 6 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 7 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 8 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 9 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 10 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 11 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 12 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 13 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 14 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 15 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 16 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 17 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 18 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 19 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 20 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 21 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 22 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 23 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 24 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 25 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 26 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 27 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 28 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 29 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 30 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 31 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  35 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 33 | Value:  1 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 34 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 35 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 36 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 37 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 38 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 39 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 40 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 41 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 42 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 43 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 44 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 45 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 46 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 47 | Value:  8 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 48 | Value:  1 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 49 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 51 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 52 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 53 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 54 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 55 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 56 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 57 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 58 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 59 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 60 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 61 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 62 | Value:  0 | Parity: 1 (valid: True) ]

# %%
controller.write_configuration(chip_key, 32) #sends only register 32
# Out:
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  35 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  35 | Parity: 0 (valid: True) ]

# %%
controller.write_configuration(chip_key, [32, 50]) #sends both register 32 and 50
# Out:
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  35 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  35 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]

# %%
chip5.config.global_threshold_address
# Out:
# 32

# %%
controller.read_configuration(chip_key)
# Out:
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 0 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 1 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 2 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 3 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 4 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 5 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 6 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 7 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 8 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 9 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 10 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 11 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 12 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 13 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 14 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 15 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 16 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 17 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 18 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 19 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 20 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 21 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 22 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 23 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 24 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 25 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 26 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 27 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 28 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 29 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 30 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 31 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 32 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 33 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 42 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 43 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 44 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 45 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 48 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 49 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 56 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 57 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 58 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 59 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 61 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 0 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 1 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 2 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 3 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 4 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 5 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 6 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 7 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 8 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 9 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 10 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 11 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 12 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 13 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 14 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 15 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 16 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 17 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 18 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 19 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 20 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 21 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 22 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 23 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 24 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 25 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 26 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 27 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 28 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 29 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 30 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 31 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 32 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 33 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 42 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 43 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 44 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 45 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 48 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 49 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 56 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 57 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 58 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 59 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 61 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config read | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-e5fa141015ba> in <module>()
# ----> 1 controller.read_configuration(chip_key)
#
# ~/anaconda3/lib/python3.6/site-packages/larpix/larpix.py in read_configuration(self, chip_key, registers, timeout, message)
#    1369             if sleep_time > 0:
#    1370                 time.sleep(sleep_time)
# -> 1371             packets, bytestream = self.read()
#    1372             self.stop_listening()
#    1373             self.store_packets(packets, bytestream, message)
#
# ~/anaconda3/lib/python3.6/site-packages/larpix/larpix.py in read(self)
#    1268         bytestream = b''
#    1269         if self.io:
# -> 1270             packets, bytestream = self.io.empty_queue()
#    1271         else:
#    1272             warnings.warn('no IO object exists, no packets will be received', RuntimeWarning)
#
# ~/anaconda3/lib/python3.6/site-packages/larpix/io/fakeio.py in empty_queue(self)
#     138             raise RuntimeError('Cannot empty queue when not'
#     139                     ' listening')
# --> 140         data = self.queue.popleft()
#     141         return data
#     142
#
# IndexError: pop from an empty deque

# %%
packets = chip5.get_configuration_packets(Packet.CONFIG_READ_PACKET)

# %%
len(packets)
# Out:
# 63

# %%
packets
# Out:
# [Packet(b'\x17\x00\x00\x00\x00\x00 '),
#  Packet(b'\x17\x04\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x08\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x0c\x00\x00\x00\x00 '),
#  Packet(b'\x17\x10\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x14\x00\x00\x00\x00 '),
#  Packet(b'\x17\x18\x00\x00\x00\x00 '),
#  Packet(b'\x17\x1c\x00\x00\x00\x00\x00'),
#  Packet(b'\x17 \x00\x00\x00\x00\x00'),
#  Packet(b'\x17$\x00\x00\x00\x00 '),
#  Packet(b'\x17(\x00\x00\x00\x00 '),
#  Packet(b'\x17,\x00\x00\x00\x00\x00'),
#  Packet(b'\x170\x00\x00\x00\x00 '),
#  Packet(b'\x174\x00\x00\x00\x00\x00'),
#  Packet(b'\x178\x00\x00\x00\x00\x00'),
#  Packet(b'\x17<\x00\x00\x00\x00 '),
#  Packet(b'\x17@\x00\x00\x00\x00\x00'),
#  Packet(b'\x17D\x00\x00\x00\x00 '),
#  Packet(b'\x17H\x00\x00\x00\x00 '),
#  Packet(b'\x17L\x00\x00\x00\x00\x00'),
#  Packet(b'\x17P\x00\x00\x00\x00 '),
#  Packet(b'\x17T\x00\x00\x00\x00\x00'),
#  Packet(b'\x17X\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\\\x00\x00\x00\x00 '),
#  Packet(b'\x17`\x00\x00\x00\x00 '),
#  Packet(b'\x17d\x00\x00\x00\x00\x00'),
#  Packet(b'\x17h\x00\x00\x00\x00\x00'),
#  Packet(b'\x17l\x00\x00\x00\x00 '),
#  Packet(b'\x17p\x00\x00\x00\x00\x00'),
#  Packet(b'\x17t\x00\x00\x00\x00 '),
#  Packet(b'\x17x\x00\x00\x00\x00 '),
#  Packet(b'\x17|\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x80\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x84\x00\x00\x00\x00 '),
#  Packet(b'\x17\x88\x00\x00\x00\x00 '),
#  Packet(b'\x17\x8c\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x90\x00\x00\x00\x00 '),
#  Packet(b'\x17\x94\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x98\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\x9c\x00\x00\x00\x00 '),
#  Packet(b'\x17\xa0\x00\x00\x00\x00 '),
#  Packet(b'\x17\xa4\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xa8\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xac\x00\x00\x00\x00 '),
#  Packet(b'\x17\xb0\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xb4\x00\x00\x00\x00 '),
#  Packet(b'\x17\xb8\x00\x00\x00\x00 '),
#  Packet(b'\x17\xbc\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xc0\x00\x00\x00\x00 '),
#  Packet(b'\x17\xc4\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xc8\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xcc\x00\x00\x00\x00 '),
#  Packet(b'\x17\xd0\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xd4\x00\x00\x00\x00 '),
#  Packet(b'\x17\xd8\x00\x00\x00\x00 '),
#  Packet(b'\x17\xdc\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xe0\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xe4\x00\x00\x00\x00 '),
#  Packet(b'\x17\xe8\x00\x00\x00\x00 '),
#  Packet(b'\x17\xec\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xf0\x00\x00\x00\x00 '),
#  Packet(b'\x17\xf4\x00\x00\x00\x00\x00'),
#  Packet(b'\x17\xf8\x00\x00\x00\x00\x00')]

# %%
# Receiving data from LArPix ASIC's
# Probably not going to work unless it's hooked up to something...

controller.start_listening()
# Data arrives...
packets, bytestream = controller.read()
#More data arrives...
packets2, bytestream2 = controller.read()
controller.stop_listening()

message = 'Data has arrived'
message2 = 'More data has arrived'

controller.store_packets(packets, bytestream, message)
controller.store_packets(packets2, bytestream2, message2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-0efb5a1e01df> in <module>()
#       4 controller.start_listening()
#       5 # Data arrives...
# ----> 6 packets, bytestream = controller.read()
#       7 #More data arrives...
#       8 packets2, bytestream2 = controller.read()
#
# ~/anaconda3/lib/python3.6/site-packages/larpix/larpix.py in read(self)
#    1268         bytestream = b''
#    1269         if self.io:
# -> 1270             packets, bytestream = self.io.empty_queue()
#    1271         else:
#    1272             warnings.warn('no IO object exists, no packets will be received', RuntimeWarning)
#
# ~/anaconda3/lib/python3.6/site-packages/larpix/io/fakeio.py in empty_queue(self)
#     138             raise RuntimeError('Cannot empty queue when not'
#     139                     ' listening')
# --> 140         data = self.queue.popleft()
#     141         return data
#     142
#
# IndexError: pop from an empty deque

# %%
from larpix.larpix import Controller, Packet
from larpix.io.fakeio import FakeIO 
from larpix.logger.stdout_logger import StdoutLogger

# %%
# Controller
##########################################################################################
controller = Controller()
controller.io = FakeIO()
controller.logger = StdoutLogger(buffer_length = 0)
controller.logger.enable()
##########################################################################################

# %%
chip1 = controller.add_chip('1-1-5')
chip1.config.global_threshold = 25
controller.write_configuration('1-1-5')
# Out:
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 0 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 1 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 2 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 3 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 4 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 5 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 6 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 7 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 8 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 9 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 10 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 11 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 12 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 13 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 14 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 15 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 16 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 17 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 18 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 19 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 20 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 21 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 22 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 23 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 24 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 25 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 26 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 27 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 28 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 29 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 30 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 31 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  25 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 33 | Value:  1 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 34 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 35 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 36 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 37 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 38 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 39 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 40 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 41 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 42 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 43 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 44 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 45 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 46 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 47 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 48 | Value:  1 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 49 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 51 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 52 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 53 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 54 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 55 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 56 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 57 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 58 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 59 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 60 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 61 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 62 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 0 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 1 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 2 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 3 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 4 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 5 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 6 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 7 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 8 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 9 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 10 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 11 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 12 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 13 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 14 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 15 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 16 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 17 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 18 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 19 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 20 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 21 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 22 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 23 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 24 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 25 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 26 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 27 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 28 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 29 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 30 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 31 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 32 | Value:  25 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 33 | Value:  1 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 34 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 35 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 36 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 37 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 38 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 39 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 40 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 41 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 42 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 43 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 44 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 45 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 46 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 47 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 48 | Value:  1 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 49 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 51 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 52 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 53 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 54 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 55 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 56 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 57 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 58 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 59 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 60 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 61 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-5 | Chip: 5 | Config write | Register: 62 | Value:  0 | Parity: 1 (valid: True) ]

# %%
packet = Packet(b'\x04\x14\x80\xc4\x03\xf2 ')
packet_bytes = packet.bytes()
pretend_input = ([packet], packet_bytes)
controller.io.queue.append(pretend_input)
controller.run(0.001, 'test run')
print(controller.reads[0])


#controller.logger.disable()
# Out:
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
# [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]

# %%
from larpix.larpix import Packet, Key

packet = Packet()
packet.chip_key = Key('1-1-1')
msgs = dataserver_message_encode([packet])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4fe5e9a88493> in <module>()
#       3 packet = Packet()
#       4 packet.chip_key = Key('1-1-1')
# ----> 5 msgs = dataserver_message_encode([packet])
#
# NameError: name 'dataserver_message_encode' is not defined

# %%
p = Packet()

# %%
p.packet_type
# Out:
# bitarray('00')

# %%
p.packet_type = 234615561372153625165360

# %%
print(p.bits)
# Out:
# bitarray('0000000000000000000000000000000000000000000000000000110001101011101000100011111010001001010111010001111011000110111011111000110000')

# %%
# Testing the write_configuration() method

from larpix.larpix import *
from larpix.io.fakeio import FakeIO
from larpix.logger.stdout_logger import StdoutLogger
from larpix.logger.h5_logger import HDF5Logger
import h5py

# %%
controller = Controller()
controller.io = FakeIO()
controller.logger = StdoutLogger(buffer_length = 0)

# %%
controller.logger.enable()

# %%
chip1 = controller.add_chip('1-1-1')
chip2 = controller.add_chip('1-1-2')
chip3 = controller.add_chip('1-1-3')

chip1.config.global_threshold = 25
chip2.config.global_threshold = 25
chip3.config.global_threshold = 25

# %%
print(controller.write_configuration('1-1-1'))
print(controller.write_configuration('1-1-2'))
print(controller.write_configuration('1-1-3'))
# Out:
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 0 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 1 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 2 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 3 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 4 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 5 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 6 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 7 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 8 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 9 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 10 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 11 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 12 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 13 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 14 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 15 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 16 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 17 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 18 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 19 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 20 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 21 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 22 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 23 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 24 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 25 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 26 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 27 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 28 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 29 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 30 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 31 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 32 | Value:  25 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 33 | Value:  1 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 42 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 43 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 44 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 45 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 48 | Value:  1 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 49 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 56 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 57 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 58 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 59 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 61 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 0 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 1 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 2 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 3 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 4 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 5 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 6 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 7 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 8 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 9 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 10 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 11 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 12 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 13 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 14 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 15 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 16 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 17 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 18 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 19 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 20 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 21 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 22 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 23 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 24 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 25 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 26 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 27 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 28 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 29 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 30 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 31 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 32 | Value:  25 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 33 | Value:  1 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 42 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 43 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 44 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 45 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 48 | Value:  1 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 49 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 56 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 57 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 58 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 59 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 61 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# None
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 0 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 1 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 2 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 3 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 4 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 5 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 6 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 7 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 8 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 9 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 10 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 11 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 12 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 13 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 14 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 15 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 16 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 17 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 18 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 19 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 20 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 21 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 22 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 23 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 24 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 25 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 26 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 27 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 28 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 29 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 30 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 31 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 32 | Value:  25 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 33 | Value:  1 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 42 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 43 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 44 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 45 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 48 | Value:  1 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 49 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 56 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 57 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 58 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 59 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 61 | Value:  16 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 0 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 1 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 2 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 3 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 4 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 5 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 6 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 7 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 8 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 9 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 10 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 11 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 12 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 13 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 14 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 15 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 16 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 17 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 18 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 19 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 20 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 21 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 22 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 23 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 24 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 25 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 26 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 27 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 28 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 29 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 30 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 31 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 32 | Value:  25 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register:
| Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 45 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 46 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 47 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 48 | Value:  1 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 49 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 51 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 52 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 53 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 54 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 55 | Value:  0 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 56 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 57 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 58 | Value:  255 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 59 | Value:  255 | Parity: 1 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 60 | Value:  0 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 61 | Value:  16 | Parity: 0 (valid: True) ]
# [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 62 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 0 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 1 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 2 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 3 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 4 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 5 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 6 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 7 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 8 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 9 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 10 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 11 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 12 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 13 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 14 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 15 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 16 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 17 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 18 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 19 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 20 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 21 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 22 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 23 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 24 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 25 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 26 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 27 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 28 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 29 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 30 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 31 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 32 | Value:  25 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 33 | Value:  1 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 42 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 43 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 44 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 45 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 48 | Value:  1 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 49 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 56 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 57 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 58 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 59 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 61 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-1 | Chip: 1 | Config write | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 0 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 1 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 2 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 3 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 4 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 5 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 6 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 7 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 8 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 9 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 10 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 11 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 12 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 13 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 14 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 15 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 16 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 17 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 18 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 19 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 20 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 21 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 22 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 23 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 24 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 25 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 26 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 27 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 28 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 29 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 30 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 31 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 32 | Value:  25 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 33 | Value:  1 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 34 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 35 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 36 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 37 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 38 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 39 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 40 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 41 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 42 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 43 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 44 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 45 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 46 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 47 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 48 | Value:  1 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 49 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 50 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 51 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 52 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 53 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 54 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 55 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 56 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 57 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 58 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 59 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 60 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 61 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-2 | Chip: 2 | Config write | Register: 62 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 0 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 1 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 2 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 3 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 4 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 5 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 6 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 7 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 8 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 9 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 10 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 11 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 12 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 13 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 14 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 15 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 16 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 17 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 18 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 19 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 20 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 21 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 22 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 23 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 24 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 25 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 26 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 27 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 28 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 29 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 30 | Value:  16 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 31 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 32 | Value:  25 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 33 | Value:  1 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 34 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 35 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 36 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 37 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 38 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 39 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 40 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 41 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 42 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 43 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 44 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 45 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 46 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 47 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 48 | Value:  1 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 49 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 50 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 51 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 52 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 53 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 54 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 55 | Value:  0 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 56 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 57 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 58 | Value:  255 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 59 | Value:  255 | Parity: 1 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 60 | Value:  0 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 61 | Value:  16 | Parity: 0 (valid: True) ]
# Record: [ Chip key: 1-1-3 | Chip: 3 | Config write | Register: 62 | Value:  0 | Parity: 1 (valid: True) ]

# %%
# "b'\x" + str(num1) + str(num2) + "\x" + str(num3) + str(num4) + "\x" + str(num5) + str(num6) + "\x" + str(num7) + str(num8)
hex_string = [b'\x04\x14\x80\xc4\x03\xf2 ', # This is the right one
             b'\x14\x14\x80\xc4\x03\xf2 ',
             b'\x24\x14\x80\xc4\x03\xf2 ',
             b'\x34\x14\x80\xc4\x03\xf2 ',
             b'\x44\x14\x80\xc4\x03\xf2 ',
             b'\x54\x14\x80\xc4\x03\xf2 ',
             b'\x64\x14\x80\xc4\x03\xf2 ',
             b'\x74\x14\x80\xc4\x03\xf2 ',
             b'\x84\x14\x80\xc4\x03\xf2 ',
             b'\x94\x14\x80\xc4\x03\xf2 ',
             b'\xa4\x14\x80\xc4\x03\xf2 ']

for i in range(0, len(hex_string)):
    packet = Packet(hex_string[i])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
# Out:
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# Record: [ Chip key: None | Chip: 5 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# Record: [ Chip key: None | Chip: 9 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# Record: [ Chip key: None | Chip: 13 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# Record: [ Chip key: None | Chip: 17 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# Record: [ Chip key: None | Chip: 21 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# Record: [ Chip key: None | Chip: 25 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# Record: [ Chip key: None | Chip: 29 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# Record: [ Chip key: None | Chip: 33 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# Record: [ Chip key: None | Chip: 37 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# Record: [ Chip key: None | Chip: 41 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]

# %%
hex_string1 = [b'\x04\x14\x80\xc4\x03\xf2 ', # This is the right one
             b'\x14\x14\x80\xc4\x03\xf2 ',
             b'\x24\x14\x80\xc4\x03\xf2 ',
             b'\x34\x14\x80\xc4\x03\xf2 ',
             b'\x44\x14\x80\xc4\x03\xf2 ',
             b'\x54\x14\x80\xc4\x03\xf2 ',
             b'\x64\x14\x80\xc4\x03\xf2 ',
             b'\x74\x14\x80\xc4\x03\xf2 ',
             b'\x84\x14\x80\xc4\x03\xf2 ',
             b'\x94\x14\x80\xc4\x03\xf2 ',
             b'\xa4\x14\x80\xc4\x03\xf2 ', 
             b'\xb4\x14\x80\xc4\x03\xf2 ',
             b'\xc4\x14\x80\xc4\x03\xf2 ',
             b'\xd4\x14\x80\xc4\x03\xf2 ',
             b'\xe4\x14\x80\xc4\x03\xf2 ',
             b'\xf4\x14\x80\xc4\x03\xf2 ']

hex_string2 = [b'\x00\x14\x80\xc4\x03\xf2 ',
             b'\x01\x14\x80\xc4\x03\xf2 ',
             b'\x02\x14\x80\xc4\x03\xf2 ',
             b'\x03\x14\x80\xc4\x03\xf2 ',
             b'\x04\x14\x80\xc4\x03\xf2 ', # This is the right one
             b'\x05\x14\x80\xc4\x03\xf2 ',
             b'\x06\x14\x80\xc4\x03\xf2 ',
             b'\x07\x14\x80\xc4\x03\xf2 ',
             b'\x08\x14\x80\xc4\x03\xf2 ',
             b'\x09\x14\x80\xc4\x03\xf2 ',
             b'\x0a\x14\x80\xc4\x03\xf2 ',
             b'\x0b\x14\x80\xc4\x03\xf2 ',
             b'\x0c\x14\x80\xc4\x03\xf2 ',
             b'\x0d\x14\x80\xc4\x03\xf2 ',
             b'\x0e\x14\x80\xc4\x03\xf2 ',
             b'\x0f\x14\x80\xc4\x03\xf2 ']

hex_string3 = [b'\x04\x04\x80\xc4\x03\xf2 ',
             b'\x04\x14\x80\xc4\x03\xf2 ', # This is the right one
             b'\x04\x24\x80\xc4\x03\xf2 ',
             b'\x04\x34\x80\xc4\x03\xf2 ',
             b'\x04\x44\x80\xc4\x03\xf2 ',
             b'\x04\x54\x80\xc4\x03\xf2 ',
             b'\x04\x64\x80\xc4\x03\xf2 ',
             b'\x04\x74\x80\xc4\x03\xf2 ',
             b'\x04\x84\x80\xc4\x03\xf2 ',
             b'\x04\x14\x80\xc4\x07\xf2 ',
             b'\x04\x14\x80\xc4\x08\xf2 ',
             b'\x04\x14\x80\xc4\x09\xf2 ',
             b'\x04\x14\x80\xc4\x0a\xf2 ',
             b'\x04\x14\x80\xc4\x0b\xf2 ',
             b'\x04\x14\x80\xc4\x0c\xf2 ',
             b'\x04\x14\x80\xc4\x0d\xf2 ',
             b'\x04\x14\x80\xc4\x0e\xf2 ',
             b'\x04\x14\x80\xc4\x0f\xf2 ']

hex_string11 = [b'\x04\x14\x80\xc4\x03\x02 ',
             b'\x04\x14\x80\xc4\x03\x12 ',
             b'\x04\x14\x80\xc4\x03\x22 ',
             b'\x04\x14\x80\xc4\x03\x32 ',
             b'\x04\x14\x80\xc4\x03\x42 ', 
             b'\x04\x14\x80\xc4\x03\x52 ',
             b'\x04\x14\x80\xc4\x03\x62 ',
             b'\x04\x14\x80\xc4\x03\x72 ',
             b'\x04\x14\x80\xc4\x03\x82 ',
             b'\x04\x14\x80\xc4\x03\x92 ',
             b'\x04\x14\x80\xc4\x03\xa2 ',
             b'\x04\x14\x80\xc4\x03\xb2 ',
             b'\x04\x14\x80\xc4\x03\xc2 ',
             b'\x04\x14\x80\xc4\x03\xd2 ',
             b'\x04\x14\x80\xc4\x03\xe2 ',
             b'\x04\x14\x80\xc4\x03\xf2 '] #

hex_string12 = [b'\x04\x14\x80\xc4\x03\xf0 ',
             b'\x04\x14\x80\xc4\x03\xf1 ',
             b'\x04\x14\x80\xc4\x03\xf2 ', #
             b'\x04\x14\x80\xc4\x03\xf3 ',
             b'\x04\x14\x80\xc4\x03\xf4 ', 
             b'\x04\x14\x80\xc4\x03\xf5 ',
             b'\x04\x14\x80\xc4\x03\xf6 ',
             b'\x04\x14\x80\xc4\x03\xf7 ',
             b'\x04\x14\x80\xc4\x03\xf8 ',
             b'\x04\x14\x80\xc4\x03\xf9 ',
             b'\x04\x14\x80\xc4\x03\xfa ',
             b'\x04\x14\x80\xc4\x03\xfb ',
             b'\x04\x14\x80\xc4\x03\xfc ',
             b'\x04\x14\x80\xc4\x03\xfd ',
             b'\x04\x14\x80\xc4\x03\xfe ',
             b'\x04\x14\x80\xc4\x03\xff ']

# %%
# b'\x04\x14\x80\xc4\x03\xf2 '
for a in range(0, len(hex_string1)):
    packet = Packet(hex_string1[a])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
    
for b in range(0, len(hex_string2)):
    packet = Packet(hex_string2[b])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
        
for c in range(0, len(hex_string3)):
    packet = Packet(hex_string3[c])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
            
for d in range(0, len(hex_string4)):
    packet = Packet(hex_string4[d])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                
for e in range(0, len(hex_string5)):
    packet = Packet(hex_string5[i])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                    
for f in range(0, len(hex_string6)):
    packet = Packet(hex_string6[f])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                        
for g in range(0, len(hex_string7)):
    packet = Packet(hex_string7[g])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                            
for h in range(0, len(hex_string8)):
    packet = Packet(hex_string8[h])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                                
for i in range(0, len(hex_string9)):
    packet = Packet(hex_string9[i])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
            
                                    
for j in range(0, len(hex_string10)):
    packet = Packet(hex_string10[j])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                                        
for k in range(0, len(hex_string11)):
    packet = Packet(hex_string11[k])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
                                            
for l in range(0, len(hex_string12)):
    packet = Packet(hex_string12[l])
    packet_bytes = packet.bytes()
    pretend_input = ([packet], packet_bytes)
    controller.io.queue.append(pretend_input) # There is now only one instance in the queue
    print(packet_bytes)
    controller.run(0.05, 'run #100') # contains a simulated start_listening(), stop_listening() feature
    
    print('\n')
    #print(controller.reads[0])
# Out:
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x14\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 5 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'$\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 9 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 13 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'D\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 17 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'T\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 21 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'd\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 25 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b't\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 29 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x84\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 33 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x94\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 37 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\xa4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 41 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\xb4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 45 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\xc4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 49 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\xd4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 53 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\xe4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 57 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\xf4\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 61 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x00\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 0 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x01\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 0 | Test | Counter: 20601 | Parity: 1 (valid: True) ]
#
#
# b'\x02\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 0 | Config write | Register: 5 | Value:  32 | Parity: 1 (valid: True) ]
#
#
# b'\x03\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 0 | Config read | Register: 5 | Value:  32 | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x05\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Test | Counter: 20601 | Parity: 1 (valid: False) ]
#
#
# b'\x06\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Config write | Register: 5 | Value:  32 | Parity: 1 (valid: False) ]
#
#
# b'\x07\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Config read | Register: 5 | Value:  32 | Parity: 1 (valid: True) ]
#
#
# b'\x08\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 2 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\t\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 2 | Test | Counter: 20601 | Parity: 1 (valid: False) ]
#
#
# b'\n\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 2 | Config write | Register: 5 | Value:  32 | Parity: 1 (valid: False) ]
#
#
# b'\x0b\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 2 | Config read | Register: 5 | Value:  32 | Parity: 1 (valid: True) ]
#
#
# b'\x0c\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 3 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\r\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 3 | Test | Counter: 20601 | Parity: 1 (valid: True) ]
#
#
# b'\x0e\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 3 | Config write | Register: 5 | Value:  32 | Parity: 1 (valid: True) ]
#
#
# b'\x0f\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 3 | Config read | Register: 5 | Value:  32 | Parity: 1 (valid: False) ]
#
#
# b'\x04\x04\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 1 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04$\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 9 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x044\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 13 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04D\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 17 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04T\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 21 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04d\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 25 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04t\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 29 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x84\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 33 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x94\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 37 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\xa4\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 41 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\xb4\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 45 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\xc4\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 49 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\xd4\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 53 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\xe4\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 57 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\xf4\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 61 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x10\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 4 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x11\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 65 | Data | Channel: 4 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x12\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 129 | Data | Channel: 4 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x13\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 193 | Data | Channel: 4 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x15\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 65 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x16\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 129 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x17\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 193 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x18\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 6 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x19\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 65 | Data | Channel: 6 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x1a\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 129 | Data | Channel: 6 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x1b\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 193 | Data | Channel: 6 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x1c\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 7 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x1d\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 65 | Data | Channel: 7 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x1e\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 129 | Data | Channel: 7 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x1f\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 193 | Data | Channel: 7 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\xa0\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x81\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x82\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123457 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x83\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123457 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x84\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123458 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x85\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123458 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x86\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123459 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x87\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123459 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x88\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123460 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x89\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123460 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x8a\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123461 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x8b\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123461 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x8c\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123462 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x8d\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123462 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x8e\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123463 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x8f\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 69 | Timestamp: 123463 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\x04\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 98880 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\x14\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 100928 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80$\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 102976 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x804\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 105024 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80D\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 107072 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80T\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 109120 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80d\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 111168 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80t\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 113216 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\x84\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 115264 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\x94\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 117312 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xa4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 119360 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xb4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 121408 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xd4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 125504 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xe4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 127552 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xf4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 129600 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc0\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 122944 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc1\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123072 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc2\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123200 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc3\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123328 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc5\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123584 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc6\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123712 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc7\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123840 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc8\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123968 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc9\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124096 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xca\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124224 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xcb\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124352 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xcc\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124480 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xcd\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124608 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xce\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124736 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xcf\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 124864 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x13\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 647744 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4#\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 1172032 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc43\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 1696320 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4C\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 2220608 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4S\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 2744896 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4c\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 3269184 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4s\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 3793472 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x83\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 4317760 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x93\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 4842048 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\xa3\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 5366336 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\xb3\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 5890624 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\xc3\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 6414912 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\xd3\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 6939200 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\xe3\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 7463488 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\xf3\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 7987776 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x00\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 25152 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x01\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 57920 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x02\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 90688 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x04\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 156224 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x05\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 188992 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x06\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 221760 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x07\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 254528 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x08\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 287296 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\t\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 320064 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\n\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 352832 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x0b\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 385600 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x0c\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 418368 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\r\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 451136 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x0e\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 483904 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x0f\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 516672 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\x02 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 0 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\x12 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 8 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03" '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 16 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x032 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 24 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03B '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 32 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03R '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 40 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03b '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 48 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03r '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 56 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\x82 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 64 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\x92 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 72 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xa2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 80 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xb2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 88 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xc2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 96 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xd2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 104 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xe2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 112 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf0 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf1 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf2 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf3 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 120 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf4 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 122 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf5 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 122 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf6 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 122 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf7 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 122 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf8 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 124 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xf9 '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 124 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xfa '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 124 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xfb '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 124 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xfc '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 126 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]
#
#
# b'\x04\x14\x80\xc4\x03\xfd '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 126 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xfe '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 123456 | ADC data: 126 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: True) ]
#
#
# b'\x04\x14\x80\xc4\x03\xff '
# Record: [ Chip key: None | Chip: 1 | Data | Channel: 5 | Timestamp: 8512064 | ADC data: 126 | FIFO Half: False | FIFO Full: False | Parity: 1 (valid: False) ]

# %%
packet2 = Packet(b'\x04\x14\x80\xc4\x03\xf2 ')
packet2_bytes = packet2.bytes()
pretend_input2 = ([packet2], packet2_bytes)
controller.io.queue.append(pretend_input2) # There is now only one instance in the queue
controller.run(0.05, 'run #100') # contains a dummy start_listening(), stop_listening() feature
#print(controller.reads[0])

# %%
chip4 = controller.add_chip('1-1-4')

chip4.config.global_threshold = 30
chip4.config.periodic_reset = 1
chip4.config.channel_mask[20] = 1

# %%
controller.write_configuration('1-1-4', 32)

# %%
chip4.config.global_threshold_address

# %%
controller.read_configuration('1-1-4')
